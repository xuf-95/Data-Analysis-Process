# %%
import numpy as np
import pandas as pd

## country_url = 'https://github.com/turingplanet/pandas-intro/blob/main/public-datasets/iris.csv'
area_df = pd.read_csv('/Users/dandypeng/Documents/Dataset/province_city_area.csv')
area_df
# Out:
#      province_name  province_code    city_name  city_code area_name  area_code
# 0              北京市         110000          市辖区     110100       东城区     110101
# 1              北京市         110000          市辖区     110100       西城区     110102
# 2              北京市         110000          市辖区     110100       朝阳区     110105
# 3              北京市         110000          市辖区     110100       丰台区     110106
# 4              北京市         110000          市辖区     110100      石景山区     110107
# ...            ...            ...          ...        ...       ...        ...
# 3062      新疆维吾尔自治区         650000  自治区直辖县级行政区划     659000      铁门关市     659006
# 3063      新疆维吾尔自治区         650000  自治区直辖县级行政区划     659000       双河市     659007
# 3064      新疆维吾尔自治区         650000  自治区直辖县级行政区划     659000     可克达拉市     659008
# 3065      新疆维吾尔自治区         650000  自治区直辖县级行政区划     659000       昆玉市     659009
# 3066      新疆维吾尔自治区         650000  自治区直辖县级行政区划     659000      胡杨河市     659010
#
# [3067 rows x 6 columns]

# %%
area_df.set_index('province_code')
# Out:
#               province_name    city_name  city_code area_name  area_code
# province_code
# 110000                  北京市          市辖区     110100       东城区     110101
# 110000                  北京市          市辖区     110100       西城区     110102
# 110000                  北京市          市辖区     110100       朝阳区     110105
# 110000                  北京市          市辖区     110100       丰台区     110106
# 110000                  北京市          市辖区     110100      石景山区     110107
# ...                     ...          ...        ...       ...        ...
# 650000             新疆维吾尔自治区  自治区直辖县级行政区划     659000      铁门关市     659006
# 650000             新疆维吾尔自治区  自治区直辖县级行政区划     659000       双河市     659007
# 650000             新疆维吾尔自治区  自治区直辖县级行政区划     659000     可克达拉市     659008
# 650000             新疆维吾尔自治区  自治区直辖县级行政区划     659000       昆玉市     659009
# 650000             新疆维吾尔自治区  自治区直辖县级行政区划     659000      胡杨河市     659010
#
# [3067 rows x 5 columns]

# %%
area_df['province_name'].value_counts()
# Out:
# 河北省         190
# 四川省         186
# 河南省         182
# 广东省         181
# 山东省         153
# 湖南省         137
# 云南省         129
# 黑龙江省        127
# 山西省         122
# 安徽省         120
# 广西壮族自治区     111
# 内蒙古自治区      108
# 陕西省         107
# 新疆维吾尔自治区    107
# 江苏省         107
# 湖北省         105
# 江西省         100
# 辽宁省         100
# 浙江省          91
# 贵州省          88
# 甘肃省          88
# 福建省          84
# 西藏自治区        78
# 吉林省          69
# 青海省          45
# 海南省          44
# 重庆市          38
# 宁夏回族自治区      22
# 上海市          16
# 天津市          16
# 北京市          16
# Name: province_name, dtype: int64
